# %%
from dotenv import load_dotenv
import os

from tinkoff.invest import CandleInterval, Client

# %%
load_dotenv()
TOKEN = os.environ['TINKOFF_API_KEY']

# %%
with Client(TOKEN) as client:
    r = client.instruments.currencies()
    print(r)
# Out:
# CurrenciesResponse(instruments=[Currency(figi='BBG0013J7V24', ticker='AMDRUB_TOM', class_code='CETS', isin='', lot=10000, currency='rub', klong=Quotation(units=0, nano=0), kshort=Quotation(units=0, nano=0), dlong=Quotation(units=0, nano=0), dshort=Quotation(units=0, nano=0), dlong_min=Quotation(units=0, nano=0), dshort_min=Quotation(units=0, nano=0), short_enabled_flag=False, name='Армянский драм', exchange='FX', nominal=MoneyValue(currency='amd', units=100, nano=0), country_of_risk='', country_of_risk_name='', trading_status=<SecurityTradingStatus.SECURITY_TRADING_STATUS_NOT_AVAILABLE_FOR_TRADING: 1>, otc_flag=False, buy_available_flag=True, sell_available_flag=True, iso_currency_name='amd', min_price_increment=Quotation(units=0, nano=2500000), api_trade_available_flag=True, uid='86d28f8d-379d-422f-b01d-c32ee0b97501', real_exchange=<RealExchange.REAL_EXCHANGE_MOEX: 1>, position_uid='4515b482-71f0-4193-aa0a-b91efdab7062', for_iis_flag=True, for_qual_investor_flag=False, weekend_flag=False, blocked_tca_flag=False, first_1min_candle_date=datetime.datetime(2022, 6, 27, 11, 35, tzinfo=datetime.timezone.utc), first_1day_candle_date=datetime.datetime(2022, 6, 27, 7, 0, tzinfo=datetime.timezone.utc)), Currency(figi='BBG0013HG026', ticker='KZTRUB_TOM', class_code='CETS', isin='', lot=10000, currency='rub', klong=Quotation(units=0, nano=0), kshort=Quotation(units=0, nano=0), dlong=Quotation(units=0, nano=0), dshort=Quotation(units=0, nano=0), dlong_min=Quotation(units=0, nano=0), dshort_min=Quotation(units=0, nano=0), short_enabled_flag=False, name='Казахстанский тенге', exchange='FX', nominal=MoneyValue(currency='kzt', units=100, nano=0), country_of_risk='', country_of_risk_name='', trading_status=<SecurityTradingStatus.SECURITY_TRADING_STATUS_NOT_AVAILABLE_FOR_TRADING: 1>, otc_flag=False, buy_available_flag=True, sell_available_flag=True, iso_currency_name='kzt', min_price_increment=Quotation(units=0, nano=2500000), api_trade_available_flag=True, uid='c7c26356-7352-4c37-8316-b1d93b18e16e', real_exchange=<RealExchange.REAL_EXCHANGE_MOEX: 1>, position_uid='6a6c93fc-a954-475f-96ed-2d8128aaaf56', for_iis_flag=True, for_qual_investor_flag=False, weekend_flag=False, blocked_tca_flag=False, first_1min_candle_date=datetime.datetime(2018, 12, 18, 8, 42, tzinfo=datetime.timezone.utc), first_1day_candle_date=datetime.datetime(2018, 12, 18, 7, 0, tzinfo=datetime.timezone.utc)), Currency(figi='BBG0013J7Y00', ticker='KGSRUB_TOM', class_code='CETS', isin='', lot=1000, currency='rub', klong=Quotation(units=0, nano=0), kshort=Quotation(units=0, nano=0), dlong=Quotation(units=0, nano=0), dshort=Quotation(units=0, nano=0), dlong_min=Quotation(units=0, nano=0), dshort_min=Quotation(units=0, nano=0), short_enabled_flag=False, name='Киргизский сом', exchange='FX', nominal=MoneyValue(currency='kgs', units=100, nano=0), country_of_risk='', country_of_risk_name='', trading_status=<SecurityTradingStatus.SECURITY_TRADING_STATUS_NOT_AVAILABLE_FOR_TRADING: 1>, otc_flag=False, buy_available_flag=True, sell_available_flag=True, iso_currency_name='kgs', min_price_increment=Quotation(units=0, nano=2500000), api_trade_available_flag=True, uid='984b69f9-f617-4a4b-92eb-826f6c68a19d', real_exchange=<RealExchange.REAL_EXCHANGE_MOEX: 1>, position_uid='18a88814-9e99-4c7e-ae30-c173e2078a61', for_iis_flag=True, for_qual_investor_flag=False, weekend_flag=False, blocked_tca_flag=False, first_1min_candle_date=datetime.datetime(2022, 11, 3, 11, 57, tzinfo=datetime.timezone.utc), first_1day_candle_date=datetime.datetime(2022, 11, 3, 7, 0, tzinfo=datetime.timezone.utc)), Currency(figi='BBG0013HQ310', ticker='UZSRUB_TOM', class_code='CETS', isin='', lot=1000000, currency='rub', klong=Quotation(units=0, nano=0), kshort=Quotation(units=0, nano=0), dlong=Quotation(units=0, nano=0), dshort=Quotation(units=0, nano=0), dlong_min=Quotation(units=0, nano=0), dshort_min=Quotation(units=0, nano=0), short_enabled_flag=False, name='Узбекский сум', exchange='FX', nominal=MoneyValue(currency='uz ...
